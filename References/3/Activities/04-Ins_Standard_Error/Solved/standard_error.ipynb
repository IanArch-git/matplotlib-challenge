# %%
# Dependencies
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import sem

# Set the seed so our data is reproducible
random.seed(42)

# %%
# Sample versus population example fuel economy
fuel_economy = pd.read_csv('../Resources/2019_fuel_economy.csv')

# First overview the data set - how many factors, etc.
print(fuel_economy.head())
# Out:
#           Type  Combined_MPG                           Make_Model
# 0  Two Seaters       21.0000                            Acura_NSX
# 1  Two Seaters       27.9406                        ALFA ROMEO_4C
# 2  Two Seaters       20.9455  Aston Martin Lagonda Ltd_Vantage V8
# 3  Two Seaters       25.9952             Audi_TT Roadster quattro
# 4  Two Seaters       27.6300                     BMW_Z4 sDrive30i

# %%
# Calculate the summary statistics and plot the histogram of the entire population data
#Can also reference a column by doing .column_name rather than ['column_name']
print(f"The mean MPG of all vehicles is: {round(fuel_economy['Combined_MPG'].mean(),2)}")
print(f"The standard deviation of all vehicle's MPG is: {round(fuel_economy.Combined_MPG.std(),2)}")
plt.hist(fuel_economy.Combined_MPG)
plt.xlabel("Fuel Economy (MPG)")
plt.ylabel("Number of Vehicles")
plt.show()
# Out:
# The mean MPG of all vehicles is: 23.33
# The standard deviation of all vehicle's MPG is: 5.94

# %%
# Calculate the summary statistics and plot the histogram of the sample data using iloc
subset = fuel_economy.iloc[range(766,856)]
print(f"The mean MPG of all vehicles is: {round(subset.Combined_MPG.mean(),2)}")
print(f"The standard deviation of all vehicle's MPG is: {round(subset.Combined_MPG.std(),2)}")
plt.hist(subset.Combined_MPG)
plt.xlabel("Fuel Economy (MPG)")
plt.ylabel("Number of Vehicles")
plt.show()
# Out:
# The mean MPG of all vehicles is: 18.48
# The standard deviation of all vehicle's MPG is: 2.41

# %%
# Calculate the summary statistics and plot the histogram of the sample data using random sampling
subset = fuel_economy.sample(90)
print(f"The mean MPG of all vehicles is: {round(subset.Combined_MPG.mean(),2)}")
print(f"The standard deviation of all vehicle's MPG is: {round(subset.Combined_MPG.std(),2)}")
plt.hist(subset.Combined_MPG)
plt.xlabel("Fuel Economy (MPG)")
plt.ylabel("Number of Vehicles")
plt.show()
# Out:
# The mean MPG of all vehicles is: 24.33
# The standard deviation of all vehicle's MPG is: 6.5

# %%
# Generate a new 30 vehicle sample and calculate the SEM of the sample
sample = fuel_economy.sample(30)
print(f"The SEM value for the sample fuel economy data is {sem(sample.Combined_MPG)}")
# Out:
# The SEM value for the sample fuel economy data is 0.6942845964442609

# %%
# Create a sample set of 10, each with 30 vehicles
vehicle_sample_set = [fuel_economy.sample(30) for x in range(0,10)]
vehicle_sample_set
# Out:
# [                             Type  Combined_MPG  \
#  506                  Midsize Cars       29.1829
#  401                  Midsize Cars       26.7896
#  1189             Standard SUV 4WD       13.9329
#  1025                Small SUV 4WD       23.1674
#  259                  Compact Cars       29.6146
#  405                  Midsize Cars       16.9762
#  305                  Compact Cars       33.3494
#  443                  Midsize Cars       25.9525
#  517                  Midsize Cars       27.7321
#  1016                Small SUV 4WD       21.1417
#  965                 Small SUV 2WD       25.0000
#  1088                Small SUV 4WD       26.1535
#  219               Subcompact Cars       20.0502
#  125              Minicompact Cars       22.3499
#  852   Standard Pick-up Trucks 4WD       15.8533
#  190               Subcompact Cars       24.6762
#  1201             Standard SUV 4WD       18.9704
#  230               Subcompact Cars       22.6853
#  290                  Compact Cars       33.2416
#  837   Standard Pick-up Trucks 4WD       16.7454
#  112              Minicompact Cars       22.1000
#  1235             Standard SUV 4WD       28.4359
#  115              Minicompact Cars       22.7422
#  701          Small Station Wagons       27.7325
#  48                    Two Seaters       17.4463
#  380                  Compact Cars       23.6775
#  136               Subcompact Cars       29.1370
#  424                  Midsize Cars       31.0000
#  1155             Standard SUV 4WD       17.4980
#  745      Small Pick-up Trucks 2WD       21.0804
#
#                                               Make_Model
#  506                             MAZDA_Mazda3 5-Door 2WD
#  401                                     BMW_530i xDrive
#  1189                                   Lamborghini_Urus
#  1025                   HYUNDAI MOTOR COMPANY_Tucson AWD
#  259                                            BMW_330i
#  405                                  BMW_M5 Competition
#  305                                     Honda_CIVIC 2Dr
#  443                     Honda_ACCORD 2.0T SPORT/TOURING
#  517                                 Mini_COOPER CLUBMAN
#  1016                                    Honda_PILOT AWD
#  965   Mitsubishi Motors Corporation_OUTLANDER SPORT 2WD
#  1088  Mitsubishi Motors Corporation_ECLIPSE CROSS ES...
#  219                      Mercedes-Benz_AMG C 63 (coupe)
#  125                                Porsche_911 Targa 4S
#  852                                   TOYOTA_TUNDRA 4WD
#  190                                        Ford_MUSTANG
#  1201                         Land Rover_Range Rover SVA
#  230                   Mercedes-Benz_E 450 (convertible)
#  290                                     Chevrolet_CRUZE
#  837                                  GMC_K10 SIERRA 4WD
#  112                   Porsche_911 Carrera GTS Cabriolet
#  1235                       TOYOTA_HIGHLANDER HYBRID AWD
#  115                               Porsche_911 Carrera S
#  701                         KIA MOTORS CORPORATION_Soul
#  48                       Mercedes-Benz_AMG GT C (coupe)
#  380                                   Volkswagen_Golf R
#  136                                             Audi_A3
#  424                   Chevrolet_CRUZE PREMIER HATCHBACK
#  1155                                   BMW_X7 xDrive50i
#  745                                   TOYOTA_TACOMA 2WD  ,
#                                        Type  Combined_MPG  \
#  383                           Compact Cars       33.8068
#  134                       Minicompact Cars       23.7980
#  1007                         Small SUV 4WD       21.2438
#  606                             Large Cars       17.8371
#  1047                         Small SUV 4WD       20.4192
#  309                           Compact Cars       31.2780
#  183                        Subcompact Cars       32.8252
#  1150                      Standard SUV 4WD       18.7509
#  265                           Compact Cars       26.7896
#  870            Special Purpose Vehicle 2WD       20.6194
#  945                          Small SUV 2WD       21.5201
#  1118                      Standard SUV 2WD       22.0000
#  379                           Compact Cars       25.7027
#  181                        Subcompact Cars       18.6287
#  1171                      Standard SUV 4WD       18.5993
#  273                           Compact Cars       22.4153
#  1159                      Standard SUV 4WD       16.4287
#  521                           Midsize Cars       27.7321
#  1211                      Standard SUV 4WD       16.7861
#  720                 Midsize Station Wagons       20.7786
#  1138                      Standard SUV 2WD       19.2405
#  286                           Compact Cars       23.7089
#  688                   Small Station Wagons       28.8278
#  1046                         Small SUV 4WD       23.5815
#  783            Standard Pick-up Trucks 2WD       21.5677
#  723                 Midsize Station Wagons       21.8116
#  893   Special Purpose Vehicle, minivan 2WD       20.5215
#  381                           Compact Cars       27.2073
#  939                          Small SUV 2WD       22.9779
#  896                          Small SUV 2WD       23.0000
#
#                                        Make_Model
#  383                             Volkswagen_Jetta
#  134                                    TOYOTA_86
#  1007                               Ford_EDGE AWD
#  606                                Dodge_Charger
#  1047                           Jeep_Wrangler 4X4
#  309                 HYUNDAI MOTOR COMPANY_Accent
#  183                              Chevrolet_SPARK
#  1150                            BMW_X5 xDrive50i
#  265                   BMW_430i xDrive Gran Coupe
#  870         Mercedes-Benz_Metris (Passenger Van)
#  945           KIA MOTORS CORPORATION_Sorento FWD
#  1118                      Chevrolet_TRAVERSE FWD
#  379                            Volkswagen_Golf R
#  181                             Chevrolet_CAMARO
#  1171                           Ford_EXPLORER AWD
#  273                   BMW_640i xDrive Gran Coupe
#  1159                Chevrolet_K1500 SUBURBAN 4WD
#  521                       Mini_COOPER COUNTRYMAN
#  1211                          MASERATI_LEVANTE S
#  720                     Jaguar_XF Sportbrake AWD
#  1138                             Lincoln_MKT FWD
#  286                             Cadillac_ATS AWD
#  688                            Chevrolet_SONIC 5
#  1046                           Jeep_Wrangler 4X4
#  783                     Ford_F150 PICKUP 2WD FFV
#  723   Mercedes-Benz_E 450 4MATIC (station wagon)
#  893                KIA MOTORS CORPORATION_Sedona
#  381                               Volkswagen_GTI
#  939                            Jeep_Cherokee FWD
#  896                                Acura_MDX FWD  ,
#                                        Type  Combined_MPG  \
#  925                          Small SUV 2WD       22.3536
#  656                             Large Cars       19.0302
#  941                          Small SUV 2WD       26.1675
#  84                        Minicompact Cars       27.1466
#  257                           Compact Cars       27.1178
#  606                             Large Cars       17.8371
#  899                          Small SUV 2WD       25.3266
#  701                   Small Station Wagons       27.7325
#  868            Special Purpose Vehicle 2WD       22.0025
#  769            Standard Pick-up Trucks 2WD       19.4955
#  971                          Small SUV 2WD       23.2973
#  462                           Midsize Cars       24.3554
#  1168                      Standard SUV 4WD       18.9076
#  892   Special Purpose Vehicle, minivan 2WD       21.9345
#  223                        Subcompact Cars       23.3607
#  896                          Small SUV 2WD       23.0000
#  1091                         Small SUV 4WD       25.5957
#  815            Standard Pick-up Trucks 4WD       17.2222
#  412                           Midsize Cars       23.2106
#  531                           Midsize Cars       25.1953
#  630                             Large Cars       34.2094
#  286                           Compact Cars       23.7089
#  961                          Small SUV 2WD       27.0000
#  136                        Subcompact Cars       29.1370
#  895   Special Purpose Vehicle, minivan 4WD       20.1322
#  336                           Compact Cars       34.0784
#  946                          Small SUV 2WD       25.3693
#  477                           Midsize Cars       31.0015
#  574                           Midsize Cars       24.6242
#  282                           Compact Cars       16.0033
#
#                                               Make_Model
#  925                                     Honda_PILOT FWD
#  656                             Lincoln_CONTINENTAL AWD
#  941                                    Jeep_Compass 4X2
#  84                                             FIAT_500
#  257                                     Audi_A4 quattro
#  606                                       Dodge_Charger
#  899                                  ALFA ROMEO_Stelvio
#  701                         KIA MOTORS CORPORATION_Soul
#  868                    Mercedes-Benz_Metris (Cargo Van)
#  769                         Chevrolet_C10 SILVERADO 2WD
#  971                     TOYOTA_HIGHLANDER LE/XLE/SE/LTD
#  462                                    INFINITI_Q50 AWD
#  1168                                Ford_Expedition 4WD
#  892                                   Honda_ODYSSEY FWD
#  223               Mercedes-Benz_AMG E53 4MATIC+ (Coupe)
#  896                                       Acura_MDX FWD
#  1091  Mitsubishi Motors Corporation_OUTLANDER SPORT 4WD
#  815                      Chevrolet_K15 SILVERADO LD 4WD
#  412                                  Buick_LACROSSE AWD
#  531                            Mini_JCW COUNTRYMAN ALL4
#  630                                     Honda_CIVIC 5Dr
#  286                                    Cadillac_ATS AWD
#  961   Mitsubishi Motors Corporation_ECLIPSE CROSS ES...
#  136                                             Audi_A3
#  895                                   TOYOTA_SIENNA AWD
#  336                                        MAZDA_MAZDA2
#  946              KIA MOTORS CORPORATION_Sportage FE FWD
#  477                        KIA MOTORS CORPORATION_Forte
#  574            Volvo Cars of North America, LLC_S90 AWD
#  282                                   BMW_M6 Gran Coupe  ,
#                                        Type  Combined_MPG  \
#  925                          Small SUV 2WD       22.3536
#  406                           Midsize Cars       20.4315
#  604                             Large Cars       22.7798
#  230                        Subcompact Cars       22.6853
#  193                        Subcompact Cars       18.2169
#  710                   Small Station Wagons       25.2689
#  770            Standard Pick-up Trucks 2WD       18.9908
#  640                             Large Cars       25.9803
#  511                           Midsize Cars       17.5069
#  479                           Midsize Cars       41.3755
#  686                   Small Station Wagons       26.7896
#  185                        Subcompact Cars       32.8252
#  77                        Minicompact Cars       17.7222
#  1112                      Standard SUV 2WD       17.5914
#  1108                         Small SUV 4WD       22.7494
#  513                           Midsize Cars       24.7223
#  84                        Minicompact Cars       27.1466
#  903                          Small SUV 2WD       26.4849
#  161                        Subcompact Cars       24.1256
#  494                           Midsize Cars       27.9953
#  890   Special Purpose Vehicle, minivan 2WD       19.9421
#  332                           Compact Cars       39.0000
#  1188                      Standard SUV 4WD       13.3061
#  600                             Large Cars       19.0620
#  773            Standard Pick-up Trucks 2WD       21.0000
#  1035                         Small SUV 4WD       24.1812
#  1234                      Standard SUV 4WD       22.6871
#  891   Special Purpose Vehicle, minivan 2WD       22.3531
#  473                           Midsize Cars       34.0109
#  1026                         Small SUV 4WD       26.1890
#
#                                       Make_Model
#  925                             Honda_PILOT FWD
#  406                            BMW_M550i xDrive
#  604                               Dodge_Charger
#  230           Mercedes-Benz_E 450 (convertible)
#  193                        Ford_MUSTANG BULLITT
#  710                 Subaru_IMPREZA 5-Door SPORT
#  770                 Chevrolet_C10 SILVERADO 2WD
#  640                HYUNDAI MOTOR COMPANY_Sonata
#  511             Mercedes-Benz_AMG E 63 S 4MATIC
#  479        KIA MOTORS CORPORATION_Optima Hybrid
#  686                BMW_330i xDrive Sports Wagon
#  185                       Chevrolet_SPARK ACTIV
#  77            Aston Martin Lagonda Ltd_DB11 V12
#  1112               Chevrolet_C1500 SUBURBAN 2WD
#  1108  Volvo Cars of North America, LLC_XC60 AWD
#  513                         Mercedes-Benz_E 300
#  84                                     FIAT_500
#  903                            Cadillac_XT4 FWD
#  161                             BMW_M240i Coupe
#  494                               LEXUS_LS 500h
#  890                         Dodge_Grand Caravan
#  332                           LEXUS_UX 250h AWD
#  1188          Jeep_Grand Cherokee Trackhawk 4x4
#  600                                Chrysler_300
#  773          Ford_F150 2WD BASE PAYLOAD LT TIRE
#  1035                          Jeep_Cherokee 4X4
#  1234                   TOYOTA_HIGHLANDER AWD LE
#  891                           Honda_ODYSSEY FWD
#  473                               Jaguar_XF AWD
#  1026                          INFINITI_QX50 AWD  ,
#                               Type  Combined_MPG  \
#  1051                Small SUV 4WD       19.3398
#  1237             Standard SUV 4WD       14.9298
#  65                    Two Seaters       25.0560
#  505                  Midsize Cars       29.5971
#  300                  Compact Cars       21.6779
#  700          Small Station Wagons       43.1750
#  14                    Two Seaters       16.8163
#  1034                Small SUV 4WD       24.0852
#  7                     Two Seaters       18.1592
#  1081                Small SUV 4WD       18.4658
#  490                  Midsize Cars       21.4965
#  11                    Two Seaters       19.2406
#  351                  Compact Cars       26.0134
#  718          Small Station Wagons       25.1898
#  59                    Two Seaters       20.7520
#  217               Subcompact Cars       21.7146
#  1147             Standard SUV 4WD       18.8003
#  174               Subcompact Cars       23.8270
#  243               Subcompact Cars       28.1232
#  51                    Two Seaters       18.0499
#  618                    Large Cars       21.1622
#  973                 Small SUV 2WD       22.4858
#  908                 Small SUV 2WD       31.7581
#  876   Special Purpose Vehicle 4WD       18.0000
#  529                  Midsize Cars       25.5420
#  753      Small Pick-up Trucks 4WD       22.3588
#  965                 Small SUV 2WD       25.0000
#  39                    Two Seaters       10.8311
#  664                    Large Cars       15.5264
#  733      Small Pick-up Trucks 2WD       23.3948
#
#                                               Make_Model
#  1051                        Jeep_Wrangler Unlimited 4X4
#  1237                      TOYOTA_LAND CRUISER WAGON 4WD
#  65                                      Porsche_Boxster
#  505                             MAZDA_Mazda3 5-Door 2WD
#  300                                     GENESIS_G70 RWD
#  700                 KIA MOTORS CORPORATION_Niro Touring
#  14                Ferrari North America, Inc._488 Pista
#  1034                                  Jeep_Cherokee 4X4
#  7                                    Chevrolet_CORVETTE
#  1081            Mercedes-Benz_AMG GLC 63 4MATIC (coupe)
#  490                                    LEXUS_GS 350 AWD
#  11                                   Chevrolet_CORVETTE
#  351                          Mercedes-Benz_C 300 4MATIC
#  718         Volvo Cars of North America, LLC_V60 CC AWD
#  59                                 NISSAN_370Z Roadster
#  217               Mercedes-Benz_AMG C 43 4MATIC (coupe)
#  1147                                            Audi_Q8
#  174                                       Buick_CASCADA
#  243                      Mini_JOHN COOPER WORKS HARDTOP
#  51                       Mercedes-Benz_AMG GT S (coupe)
#  618                                     GENESIS_G80 RWD
#  973                                    Volkswagen_Atlas
#  908                               Chevrolet_EQUINOX FWD
#  876                              Lincoln_MKT LIVERY AWD
#  529                       Mini_COOPER S COUNTRYMAN ALL4
#  753                                      GMC_CANYON 4WD
#  965   Mitsubishi Motors Corporation_OUTLANDER SPORT 2WD
#  39                       Lamborghini_Aventador Roadster
#  664                              Mercedes-Benz_AMG S 65
#  733                              Chevrolet_COLORADO 2WD  ,
#                               Type  Combined_MPG  \
#  824   Standard Pick-up Trucks 4WD       20.9759
#  581                    Large Cars       23.8507
#  843   Standard Pick-up Trucks 4WD       20.7871
#  1060                Small SUV 4WD       23.5598
#  1149             Standard SUV 4WD       22.4296
#  654                    Large Cars       28.7852
#  561                  Midsize Cars       46.2351
#  353                  Compact Cars       26.9404
#  116              Minicompact Cars       24.1780
#  595                    Large Cars       24.5660
#  227               Subcompact Cars       24.8683
#  546                  Midsize Cars       27.0000
#  547                  Midsize Cars       14.1837
#  302                  Compact Cars       34.5174
#  1178             Standard SUV 4WD       17.3200
#  432                  Midsize Cars       16.9149
#  529                  Midsize Cars       25.5420
#  944                 Small SUV 2WD       24.5180
#  757      Small Pick-up Trucks 4WD       17.1221
#  556                  Midsize Cars       43.6328
#  1186             Standard SUV 4WD       16.6887
#  705          Small Station Wagons       28.0000
#  201               Subcompact Cars       22.4496
#  117              Minicompact Cars       22.6436
#  427                  Midsize Cars       25.7929
#  1217             Standard SUV 4WD       15.1954
#  790   Standard Pick-up Trucks 2WD       16.8203
#  13                    Two Seaters       17.7310
#  1205             Standard SUV 4WD       29.7729
#  1180             Standard SUV 4WD       16.8656
#
#                                   Make_Model
#  824                    Ford_F150 PICKUP 4WD
#  581                                BMW_740i
#  843                     Honda_RIDGELINE AWD
#  1060    Land Rover_Range Rover Evoque 286HP
#  1149                       BMW_X5 xDrive40i
#  654        KIA MOTORS CORPORATION_Optima FE
#  561              TOYOTA_CAMRY HYBRID XLE/SE
#  353            Mercedes-Benz_CLA 250 4MATIC
#  116         Porsche_911 Carrera S Cabriolet
#  595                        Chevrolet_IMPALA
#  227             Mercedes-Benz_C 300 (Coupe)
#  546                     NISSAN_SENTRA NISMO
#  547   Rolls-Royce Motor Cars Limited_Wraith
#  302                         Honda_CIVIC 2Dr
#  1178                    GMC_K1500 YUKON 4WD
#  432                        Dodge_Challenger
#  529           Mini_COOPER S COUNTRYMAN ALL4
#  944      KIA MOTORS CORPORATION_Sorento FWD
#  757                 NISSAN_FRONTIER 4WD FFV
#  556                TOYOTA_AVALON HYBRID XLE
#  1186                Jeep_Grand Cherokee 4X4
#  705                      NISSAN_Rogue Sport
#  201                            INFINITI_Q60
#  117         Porsche_911 Carrera S Cabriolet
#  427                        Chevrolet_MALIBU
#  1217             Mercedes-Benz_AMG GLE 63 S
#  790                      GMC_C10 SIERRA 2WD
#  13      Ferrari North America, Inc._488 gtb
#  1205                      LEXUS_RX 450h AWD
#  1180                    GMC_K1500 YUKON 4WD  ,
#                                       Type  Combined_MPG  \
#  304                          Compact Cars       31.6578
#  614                            Large Cars       19.6948
#  802           Standard Pick-up Trucks 2WD       12.1700
#  147                       Subcompact Cars       25.0431
#  775           Standard Pick-up Trucks 2WD       19.0000
#  523                          Midsize Cars       25.8524
#  844           Standard Pick-up Trucks 4WD       17.6143
#  102                      Minicompact Cars       21.9000
#  244                       Subcompact Cars       26.2704
#  617                            Large Cars       20.2026
#  1217                     Standard SUV 4WD       15.1954
#  48                            Two Seaters       17.4463
#  1154                     Standard SUV 4WD       21.7788
#  376                          Compact Cars       28.7418
#  63                            Two Seaters       16.4000
#  417                          Midsize Cars       22.5028
#  878   Special Purpose Vehicle cab chassis       16.0000
#  808           Standard Pick-up Trucks 4WD       16.2649
#  109                      Minicompact Cars       22.8334
#  1005                        Small SUV 4WD       25.0000
#  531                          Midsize Cars       25.1953
#  537                          Midsize Cars       29.0000
#  84                       Minicompact Cars       27.1466
#  1079                        Small SUV 4WD       21.0340
#  1176                     Standard SUV 4WD       22.0000
#  54                            Two Seaters       22.7835
#  546                          Midsize Cars       27.0000
#  432                          Midsize Cars       16.9149
#  1134                     Standard SUV 2WD       17.5914
#  932                         Small SUV 2WD       19.7055
#
#                                            Make_Model
#  304                                  Honda_CIVIC 2Dr
#  614                                  GENESIS_G80 AWD
#  802           Roush Industries, Inc._F150 Pickup 2WD
#  147                                   Audi_TTS Coupe
#  775               Ford_F150 2WD BASE PAYLOAD LT TIRE
#  523                      Mini_COOPER COUNTRYMAN ALL4
#  844                                 NISSAN_TITAN 4WD
#  102              Porsche_911 Carrera 4 GTS Cabriolet
#  244                   Mini_JOHN COOPER WORKS HARDTOP
#  617                                  GENESIS_G80 RWD
#  1217                      Mercedes-Benz_AMG GLE 63 S
#  48                    Mercedes-Benz_AMG GT C (coupe)
#  1154                                BMW_X7 xDrive40i
#  376                                Volkswagen_Beetle
#  63                                Porsche_911 GT3 RS
#  417                                     Cadillac_CTS
#  878          Chevrolet_C10 SILVERADO 2WD CAB CHASSIS
#  808                      Chevrolet_K10 SILVERADO 4WD
#  109                    Porsche_911 Carrera Cabriolet
#  1005                               Ford_ECOSPORT AWD
#  531                         Mini_JCW COUNTRYMAN ALL4
#  537                    NISSAN_ALTIMA AWD SR/PLATINUM
#  84                                          FIAT_500
#  1079         Mercedes-Benz_AMG GLC 43 4MATIC (coupe)
#  1176                                  GMC_ACADIA AWD
#  54                              Mercedes-Benz_SL 450
#  546                              NISSAN_SENTRA NISMO
#  432                                 Dodge_Challenger
#  1134                          GMC_C1500 YUKON XL 2WD
#  932   HYUNDAI MOTOR COMPANY_Santa Fe XL Ultimate FWD  ,
#                               Type  Combined_MPG  \
#  599                    Large Cars       22.7798
#  994                 Small SUV 4WD       22.0847
#  860   Special Purpose Vehicle 2WD       18.3156
#  607                    Large Cars       21.4055
#  638                    Large Cars       57.7824
#  1009                Small SUV 4WD       23.0643
#  581                    Large Cars       23.8507
#  711          Small Station Wagons       24.8900
#  1149             Standard SUV 4WD       22.4296
#  107              Minicompact Cars       22.3499
#  610                    Large Cars       18.8946
#  1001                Small SUV 4WD       24.1864
#  760      Small Pick-up Trucks 4WD       18.4907
#  543                  Midsize Cars       32.2567
#  177               Subcompact Cars       22.4764
#  1157             Standard SUV 4WD       16.5982
#  570                  Midsize Cars       52.3985
#  787   Standard Pick-up Trucks 2WD       21.0999
#  1187             Standard SUV 4WD       14.9466
#  914                 Small SUV 2WD       24.5154
#  1236             Standard SUV 4WD       28.9073
#  399                  Midsize Cars       11.7710
#  835   Standard Pick-up Trucks 4WD       16.7517
#  28                    Two Seaters       17.5299
#  999                 Small SUV 4WD       27.2150
#  691          Small Station Wagons       36.4670
#  687          Small Station Wagons       24.3822
#  210               Subcompact Cars       22.8079
#  278                  Compact Cars       20.1654
#  433                  Midsize Cars       21.4055
#
#                              Make_Model
#  599                       Chrysler_300
#  994                 Buick_ENVISION AWD
#  860         Ford_RANGER 2WD INCOMPLETE
#  607                  Dodge_Charger AWD
#  638   HYUNDAI MOTOR COMPANY_Ioniq Blue
#  1009                   Ford_ESCAPE AWD
#  581                           BMW_740i
#  711           Volkswagen_Golf Alltrack
#  1149                  BMW_X5 xDrive40i
#  107   Porsche_911 Carrera 4S Cabriolet
#  610                    Ford_TAURUS AWD
#  1001             Chevrolet_EQUINOX AWD
#  760                  TOYOTA_TACOMA 4WD
#  543                      NISSAN_SENTRA
#  177                   Chevrolet_CAMARO
#  1157             Cadillac_ESCALADE 4WD
#  570                       TOYOTA_PRIUS
#  787                 GMC_C10 SIERRA 2WD
#  1187       Jeep_Grand Cherokee SRT 4x4
#  914                      Ford_EDGE FWD
#  1236   TOYOTA_HIGHLANDER HYBRID AWD LE
#  399                   Bentley_Mulsanne
#  835                 GMC_K10 SIERRA 4WD
#  28     Jaguar_F-TYPE R AWD Convertible
#  999              Chevrolet_EQUINOX AWD
#  691                          Honda_FIT
#  687             Buick_REGAL TOUR X AWD
#  210                       LEXUS_RC 350
#  278                       BMW_M4 Coupe
#  433                Dodge_Challenger GT  ,
#                               Type  Combined_MPG  \
#  1112             Standard SUV 2WD       17.5914
#  923                 Small SUV 2WD       28.3439
#  36                    Two Seaters       18.4489
#  99               Minicompact Cars       22.3791
#  1003                Small SUV 4WD       18.8946
#  1059                Small SUV 4WD       24.5353
#  938                 Small SUV 2WD       25.2188
#  739      Small Pick-up Trucks 2WD       21.5263
#  746      Small Pick-up Trucks 2WD       20.6457
#  840   Standard Pick-up Trucks 4WD       17.4563
#  853   Standard Pick-up Trucks 4WD       14.4679
#  1171             Standard SUV 4WD       18.5993
#  1133             Standard SUV 2WD       17.5914
#  45                    Two Seaters       29.0373
#  305                  Compact Cars       33.3494
#  128              Minicompact Cars       20.6637
#  1236             Standard SUV 4WD       28.9073
#  773   Standard Pick-up Trucks 2WD       21.0000
#  626                    Large Cars       29.7143
#  1237             Standard SUV 4WD       14.9298
#  1169             Standard SUV 4WD       18.0000
#  541                  Midsize Cars       24.2647
#  574                  Midsize Cars       24.6242
#  42                    Two Seaters       15.0849
#  105              Minicompact Cars       22.5560
#  188               Subcompact Cars       30.1309
#  1221             Standard SUV 4WD       19.5253
#  1010                Small SUV 4WD       25.9965
#  148               Subcompact Cars       26.7488
#  74                    Two Seaters       21.3150
#
#                                      Make_Model
#  1112              Chevrolet_C1500 SUBURBAN 2WD
#  923                             Honda_CR-V FWD
#  36      Jaguar_F-TYPE SVR AWD Convertible GEN2
#  99             Porsche_911 Carrera 4 Cabriolet
#  1003                         Dodge_Journey AWD
#  1059       Land Rover_Range Rover Evoque 237HP
#  938                          Jeep_Cherokee FWD
#  739                        Honda_RIDGELINE FWD
#  746                          TOYOTA_TACOMA 2WD
#  840                     GMC_K10 SIERRA 4WD AT4
#  853                          TOYOTA_TUNDRA 4WD
#  1171                         Ford_EXPLORER AWD
#  1133                    GMC_C1500 YUKON XL 2WD
#  45                                  MAZDA_MX-5
#  305                            Honda_CIVIC 2Dr
#  128                        Porsche_911 Turbo S
#  1236           TOYOTA_HIGHLANDER HYBRID AWD LE
#  773         Ford_F150 2WD BASE PAYLOAD LT TIRE
#  626                               Honda_ACCORD
#  1237             TOYOTA_LAND CRUISER WAGON 4WD
#  1169                   Ford_Expedition MAX 4WD
#  541                              NISSAN_MAXIMA
#  574   Volvo Cars of North America, LLC_S90 AWD
#  42                  Lamborghini_Huracan Spyder
#  105                     Porsche_911 Carrera 4S
#  188                            Ford_Fiesta FWD
#  1221              Mercedes-Benz_GLE 400 4MATIC
#  1010                           GMC_TERRAIN AWD
#  148                       BMW_230i Convertible
#  74                          Porsche_Cayman GTS  ,
#                               Type  Combined_MPG  \
#  1150             Standard SUV 4WD       18.7509
#  1210             Standard SUV 4WD       15.3607
#  6                     Two Seaters       14.5801
#  818   Standard Pick-up Trucks 4WD       20.0000
#  901                 Small SUV 2WD       28.4076
#  618                    Large Cars       21.1622
#  415                  Midsize Cars       22.0000
#  1042                Small SUV 4WD       25.0366
#  1214             Standard SUV 4WD       18.9393
#  188               Subcompact Cars       30.1309
#  144               Subcompact Cars       24.0356
#  386                  Compact Cars       27.5279
#  909                 Small SUV 2WD       25.3669
#  914                 Small SUV 2WD       24.5154
#  154               Subcompact Cars       25.7086
#  544                  Midsize Cars       29.9942
#  254                  Compact Cars       26.3463
#  517                  Midsize Cars       27.7321
#  170               Subcompact Cars       18.5025
#  104              Minicompact Cars       23.7716
#  806   Standard Pick-up Trucks 4WD       19.1431
#  351                  Compact Cars       26.0134
#  1167             Standard SUV 4WD       15.1196
#  450                  Midsize Cars       51.9827
#  198               Subcompact Cars       23.0000
#  1068                Small SUV 4WD       21.8239
#  200               Subcompact Cars       25.2191
#  392                  Midsize Cars       19.7059
#  1129             Standard SUV 2WD       20.6817
#  1004                Small SUV 4WD       25.9757
#
#                                Make_Model
#  1150                    BMW_X5 xDrive50i
#  1210                MASERATI_LEVANTE GTS
#  6                     Chevrolet_CORVETTE
#  818   Ford_F150 4WD BASE PAYLOAD LT TIRE
#  901                         Buick_ENCORE
#  618                      GENESIS_G80 RWD
#  415                      Buick_REGAL AWD
#  1042                    Jeep_Compass 4X4
#  1214     Mercedes-Benz_AMG GLE 43 4MATIC
#  188                      Ford_Fiesta FWD
#  144                              Audi_S5
#  386                     Volkswagen_Jetta
#  909                Chevrolet_EQUINOX FWD
#  914                        Ford_EDGE FWD
#  154          BMW_430i xDrive Convertible
#  544                        NISSAN_SENTRA
#  254                 Acura_TLX FWD A-SPEC
#  517                  Mini_COOPER CLUBMAN
#  170       BMW_M4 Convertible Competition
#  104               Porsche_911 Carrera 4S
#  806          Chevrolet_K10 SILVERADO 4WD
#  351           Mercedes-Benz_C 300 4MATIC
#  1167               Dodge_Durango SRT AWD
#  450                        Honda_INSIGHT
#  198     Ford_MUSTANG PERFORMANCE PACKAGE
#  1068                    LEXUS_RX 350 AWD
#  200                         INFINITI_Q60
#  392                    ALFA ROMEO_Giulia
#  1129                      GMC_ACADIA FWD
#  1004                       FIAT_500X AWD  ]

# %%
# Generate the plot data for each sample 
means = [sample.Combined_MPG.mean() for sample in vehicle_sample_set]
standard_errors = [sem(sample.Combined_MPG) for sample in vehicle_sample_set]
x_axis = np.arange(0, len(vehicle_sample_set), 1) + 1

# %%
# Setting up the plot
fig, ax = plt.subplots()
ax.errorbar(x_axis, means, standard_errors, fmt="o")
ax.set_xlim(0, len(vehicle_sample_set) + 1)
ax.set_ylim(20,28)
ax.set_xlabel("Sample Number")
ax.set_ylabel("Mean MPG")
plt.show()
